# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelwvt/SGEB-FBRH/blob/main/CALCULADORA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CALCULADORA

# %%
def calculadora():
  print("Bem-vindos à calculadora!")
  print("Selecione uma operação:")
  print("1. Soma")
  print("2. Subtração")
  print("3. Multiplicações")
  print("4.Divisão")

  escolha = input ("Digite o número da operação:")
  if escolha == "1"
   num1 = float(input("Digite o primeiro número:"))
   num2 = float(input("Digite o segundo número: "))
  resultado = num1 + num2
  print(f"{num1}+{num2}={resultado}")
  elif escolha == "2":
   num1 = float(input("Digite o primeiro número:"))
   num2 = float(input("Digite o segundo número: "))
   resultado = num1 - num2
  print(f"{num1}-{num2}={resultado}")
  elif escolha == "3":
